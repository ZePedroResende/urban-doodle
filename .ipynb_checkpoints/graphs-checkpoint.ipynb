# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import pandas as pd
import numpy as np
import networkx as nx
import  itertools as it
import matplotlib.pyplot as plt
from scipy.cluster import hierarchy as hc
import re

# %%
#data = arff.loadarff("datasets/treated.csv")

#df = pd.DataFrame(data[0])
from scipy.spatial.distance import pdist
df = pd.read_csv("datasets/treated.csv", na_values=["?"])
df.head()
# Out:
#    'age'  'bp'   'sg'  'al'  'su'   'rbc'      'pc'       'pcc'        'ba'  \
# 0   48.0  80.0  1.020   1.0   0.0     NaN    normal  notpresent  notpresent
# 1    7.0  50.0  1.020   4.0   0.0     NaN    normal  notpresent  notpresent
# 2   62.0  80.0  1.010   2.0   3.0  normal    normal  notpresent  notpresent
# 3   48.0  70.0  1.005   4.0   0.0  normal  abnormal     present  notpresent
# 4   51.0  80.0  1.010   2.0   0.0  normal    normal  notpresent  notpresent
#
#    'bgr'  ...  'pcv'  'wbcc'  'rbcc'  'htn'  'dm' 'cad' 'appet' 'pe' 'ane'  \
# 0  121.0  ...     44    7800     5.2    yes   yes    no    good   no    no
# 1    NaN  ...     38    6000     NaN     no    no    no    good   no    no
# 2  423.0  ...     31    7500     NaN     no   yes    no    poor   no   yes
# 3  117.0  ...     32    6700     3.9    yes    no    no    poor  yes   yes
# 4  106.0  ...     35    7300     4.6     no    no    no    good   no    no
#
#   'class'
# 0     ckd
# 1     ckd
# 2     ckd
# 3     ckd
# ...

# %%
df.replace('?', np.NaN)
#df['rbc'].replace(df['rbc'].head()[0], inplace=True)


df.isnull().values.any()
df.isnull().sum()
col = df.columns.tolist()

# %%
corr = 1 - df.corr() 

corr_condensed = hc.distance.squareform(corr)
z = hc.linkage(corr_condensed, method='average')
hc.dendrogram(z, labels=corr.columns)
plt.show()

# %%
graph = nx.Graph()


for index, row in df.iterrows():
    for i in it.combinations(col,2):
        if not pd.isnull(row[i[0]]) and not pd.isnull( row[i[1]]):
            node_a = i[0]+ str(row[i[0]])
            node_b = i[1]+ str(row[i[1]])
        
            if graph.has_edge(node_a, node_b):
                    graph[node_a][node_b]['weight'] += 1
            else:
                    graph.add_edge(node_a,node_b, weight=1)
        

nx.draw(graph, layout=nx.spring_layout(graph,  k=0.3*1/np.sqrt(len(graph.nodes())), iterations=20), scale=25)
plt.figure(3, figsize=(300, 300))

plt.show()

# %%
nx.draw_networkx(graph, pos=nx.random_layout(graph), width=[d['weight'] for _, _, d in graph.edges(data=True)])
plt.show()

# %%
G = graph
edges,weights = zip(*nx.get_edge_attributes(G,'weight').items())

pos = nx.spring_layout(G)
nx.draw(G, pos, node_color='b', edgelist=edges, edge_color=weights, width=10.0)
plt.figure(3,figsize=(100, 100))
plt.show()

# %%
node_list = graph.number_of_nodes()
all_weights = []
for (node1,node2,data) in graph.edges(data=True):
    all_weights.append(data['weight']) #we'll use this when determining edge thickness
unique_weights = list(set(all_weights))

for weight in unique_weights:
    weighted_edges = [(node1,node2) for (node1,node2,edge_attr) in G.edges(data=True) if edge_attr['weight']==weight]
    width = weight
    nx.draw(G,pos,edgelist=weighted_edges,width=width)

width = (weight*node_list)/sum(all_weights)

plt.show()

# %%
def value(graph, origin, to_find):
    lengths=nx.single_source_dijkstra_path_length(gra4ph,origin, weight='weight')
    currency_nodes = [ n for n in lengths.keys() if re.findall(to_find,n)]
    return [(n,len) for (n,len) in lengths.items() if n in currency_nodes]

# %%
value(graph, "\'age\'48.0","\'rbc'(normal|abnormal)")
# Out:
# [("'rbc'abnormal", 2), ("'rbc'normal", 2)]

# %%
value(graph, "\'bp\'80.0","\'rbc'(normal|abnormal)")
# Out:
# ["'age'48.0", "'bp'80.0", "'sg'1.02", "'al'1.0", "'su'0.0", "'pc'normal", "'pcc'notpresent", "'ba'notpresent", "'bgr'121.0", "'bu'36.0", "'sc'1.2", "'hemo'15.4", "'pcv'44", "'wbcc'7800", "'rbcc'5.2", "'htn'yes", "'dm'yes", "'cad'no", "'appet'good", "'pe'no", "'ane'no", "'class'ckd", "'age'7.0", "'bp'50.0", "'al'4.0", "'bu'18.0", "'sc'0.8", "'hemo'11.3", "'pcv'38", "'wbcc'6000", "'htn'no", "'dm'no", "'age'62.0", "'sg'1.01", "'al'2.0", "'su'3.0", "'rbc'normal", "'bgr'423.0", "'bu'53.0", "'sc'1.8", "'hemo'9.6", "'pcv'31", "'wbcc'7500", "'appet'poor", "'ane'yes", "'bp'70.0", "'sg'1.005", "'pc'abnormal", "'pcc'present", "'bgr'117.0", "'bu'56.0", "'sc'3.8", "'sod'111.0", "'pot'2.5", "'hemo'11.2", "'pcv'32", "'wbcc'6700", "'rbcc'3.9", "'pe'yes", "'age'51.0", "'bgr'106.0", "'bu'26.0", "'sc'1.4", "'hemo'11.6", "'pcv'35", "'wbcc'7300", "'rbcc'4.6", "'age'60.0", "'bp'90.0", "'sg'1.015", "'al'3.0", "'bgr'74.0", "'bu'25.0", "'sc'1.1", "'sod'142.0", "'pot'3.2", "'hemo'12.2", "'pcv'39", "'rbcc'4.4"
# ...

# %%
value(graph, "'sg'1.02","\'rbcc'.*")
# Out:
# [("'rbcc'3.7", 1),
#  ("'rbcc'4.3", 1),
#  ("'rbcc'3.8", 1),
#  ("'rbcc'4.4", 1),
#  ("'rbcc'3.1", 1),
#  ("'rbcc'3.9", 1),
#  ("'rbcc'6.0", 1),
#  ("'rbcc'6.2", 1),
#  ("'rbcc'5.1", 1),
#  ("'rbcc'5.0", 2),
#  ("'rbcc'5.7", 2),
#  ("'rbcc'6.5", 2),
#  ("'rbcc'6.3", 2),
#  ("'rbcc'5.2", 2),
#  ("'rbcc'5.3", 2),
#  ("'rbcc'4", 2),
#  ("'rbcc'4.5", 2),
#  ("'rbcc'4.6", 2),
#  ("'rbcc'3.4", 2),
#  ("'rbcc'3.6", 2),
#  ("'rbcc'3.3", 2),
#  ("'rbcc'4.9", 2),
#  ("'rbcc'4.7", 2),
#  ("'rbcc'3.2", 2),
#  ("'rbcc'2.6", 2),
#  ("'rbcc'4.1", 2),
#  ("'rbcc'3.0", 2),
#  ("'rbcc'2.7", 2),
#  ("'rbcc'4.2", 2),
#  ("'rbcc'8.0", 2),
#  ("'rbcc'\t?", 2),
#  ("'rbcc'5", 2),
#  ("'rbcc'4.0", 2),
#  ("'rbcc'2.4", 2),
#  ("'rbcc'2.5", 2),
#  ("'rbcc'3", 2),
#  ("'rbcc'4.8", 2),
#  ("'rbcc'5.6", 2),
#  ("'rbcc'6.1", 2),
#  ("'rbcc'5.8", 2),
#  ("'rbcc'5.5", 2),
#  ("'rbcc'3.5", 2),
#  ("'rbcc'5.4", 2),
#  ("'rbcc'6.4", 2),
#  ("'rbcc'5.9", 2),
#  ("'rbcc'2.8", 2),
#  ("'rbcc'2.1", 2),
# ...
